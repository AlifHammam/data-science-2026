# %% [markdown]
# <a href="https://colab.research.google.com/github/AlifHammam/data-science-2026/blob/main/Pertemuan1_AlifHamammamMultazam_240401010043.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pertemuan 1 - Pengenalan Data Science
#
# **Nama Lengkap:** Alif Hammam Multazam
# **NIM:** 240401010043
# **Kelas:** IF403

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Alif Hammam Multazam"  # String
angkatan = 2024                   # Integer
ipk = 3.96                        # Float
aktif = True                      # Boolean

print(f"Nama     : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")
# Out:
# Nama     : Alif Hamammam Multazam
# Angkatan : 2024
# IPK      : 3.96
# Aktif    : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("Tools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Alif Hamammam Multazam", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Alif Hamammam Multazam dari Informatika, angkatan 2024.

# %% [markdown]
# ## Kesimpulan
#
# Pada praktikum pertemuan pertama ini saya mempelajari pengenalan Data Science serta mengenal beberapa tools yang digunakan dalam proses pembelajaran, yaitu Python, Google Colab, Jupyter Notebook, dan GitHub.
#
# Melalui latihan kode Python sederhana, saya memahami cara menampilkan output, menggunakan variabel, mengenal tipe data dasar, membuat list, melakukan perulangan, serta membuat fungsi sederhana. Kegiatan ini menjadi langkah awal untuk memahami pemrograman yang nantinya digunakan dalam analisis data.
#
# Keterbatasan pada praktikum ini adalah materi masih bersifat dasar dan belum membahas pengolahan data secara langsung. Namun, praktikum ini sangat membantu dalam mempersiapkan lingkungan kerja dan pemahaman dasar sebelum mempelajari materi Data Science yang lebih lanjut.
